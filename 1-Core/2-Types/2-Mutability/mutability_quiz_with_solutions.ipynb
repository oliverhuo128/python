# %% [markdown]
# ### Concept Check: Mutability Quiz
#
# Before you run each block of python code, can you predict what the value of `z` will be?
#
# Then check your answers by running the code
#
# #### Question 1
# ```
# x = 10
# y = x
# z = y
# y = 20
#
# # value of z=?
#
# # a) 10
# # b) 20
# # c) [x]
# # d) [y]
# # e) [x, y]
# ```

# %%
# Record your answer here
# z = 

# Use the space below to check if you were correct
x = 10
y = x
z = y
y = 20
z
# Out:
# 10

# %% [markdown]
# #### Question 2
# ```
# x = []
# z = x
# y = x
# y.append(1)
#
# # value of z=?
#
# # a) []
# # b) [x, 1]
# # c) [1,x]
# # d) [1]
# # e) 1
#
# ```

# %%
# Record your answer here
# z = 

# Use the space below to check if you were correct
x = []
z = x
y = x
y.append(1)
z
# Out:
# [1]

# %% [markdown]
# #### Question 3
# ```
# z = 10
# y = z
# y = y+1
# z = z+1
#
# # value of z=?
# # a) 10
# # b) 11
# # c) 12
# # d) [10, 1]
# # e) [10, 1, 1]
#
# ```

# %%
# Record your answer here
# z = 

# Use the space below to check if you were correct
z = 10
y = z
y = y+1
z = z+1
z
# Out:
# 11

# %% [markdown]
# #### Question 4
# ```
# z = 10
# my_list = [z]
# my_list[0] = my_list[0]+1
#
# # value of z=?
# # a) 10
# # b) 11
# # c) 10, 1
# # d) [0, 1]
# # e) 0
#
# ```

# %%
# Record your answer here
# z = 

# Use the space below to check if you were correct
z = 10
my_list = [z]
my_list[0] = my_list[0]+1
z
# Out:
# 10

# %% [markdown]
# #### Question 5
# ```
# z = 10
# d = {'z':z}
# d['z'] = 20
#
# # value of z=?
#
# # value of z=?
# # a) z
# # b) 'z'
# # c) 10
# # d) 20
# # e) {'z':20}
#
# ```

# %%
# Record your answer here
# z = 

# Use the space below to check if you were correct
z = 10
d = {'z':z}
d['z'] = 20
z
# Out:
# 10

# %% [markdown]
# #### Question 6
# ```
# x = 10
# y = x
# y = 20
# z = y
#
# # value of z=?
#
# # a) 10
# # b) 20
# # c) [10, 20]
# # d) [20, 10]
# # e) []
#
# ```

# %%
# Record your answer here
# z = 

# Use the space below to check if you were correct
x = 10
y = x
y = 20
z = y
z
# Out:
# 20

# %% [markdown]
# ## Second set of questions:
#
# #### Question 7
# ```
# x = [10, 20, 30]
# y = [40, 50, 60]
# z = x+y
#
# # what is the value of z[1]?
#
# # a) 10
# # b) 20
# # c) 50
# # d) 70
# # e) [10, 40]
# # f) [20, 50]
# ```

# %%
# Record your answer here
# z[1] = 

# Use the space below to check if you were correct
x = [10, 20, 30]
y = [40, 50, 60]
z = x+y
z[1]
# Out:
# 20

# %% [markdown]
# #### Question 8
# ```
# x = [10, 20, 30]
# y = [40, 50, 60]
# z = [x,y]
#
# # what is the value of z[1]?
#
# # a) 10
# # b) 20
# # c) [10, 40]
# # d) [20, 50]
# # e) [10, 20, 30]
# # f) [40, 50, 60]
# ```

# %%
# Record your answer here
# z[1] = 

# Use the space below to check if you were correct
x = [10, 20, 30]
y = [40, 50, 60]
z = [x,y]
z[1]
# Out:
# [40, 50, 60]

# %% [markdown]
# #### Question 9
# ```
# x = ('a', 2, [2,3,4])
# x[2].append(5)
#
# Which of the following best describes the above code:
#
# # a) This causes an error, because element [2] is an integer, which doesn't support the 'append' method
# # b) This causes an error, because x is a tuple, meaning it can't be modified
# # c) The statements don't produce an error, because none of the ids of the tuple are modified.
# # d) The statements don't produce an error, because a copy of the values is created, leaving the originals unchanged.
# ```

# %%
# Record your answer here
# c

# Use the space below to check if you were correct
x = ('a', 2, [2,3,4])
x[2].append(5)

# %% [markdown]
# #### Question 10
# ```
# x = ['Alice', 'Bob', ('Charlie', 'Brown')]
# x[2].append('Junior')
#
#
# Which of the following best describes the above code:
#
# # a) This list element is now modified to contain ('Charlie Brown Junior')
# # b) This list element is now modified to contain ('Charlie', 'Brown', 'Junior')
# # c) This causes an error, because lists can't be modified
# # d) This causes an error, because tuples can't be modified
# # e) This causes an error, because lists can't contain tuples
# ```

# %%
# Record your answer here
# d

# Use the space below to check if you were correct
x = ['Alice', 'Bob', ('Charlie', 'Brown')]
x[2].append('Junior')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\GARETH~1\AppData\Local\Temp/ipykernel_15672/1189191254.py in <module>
#       4 # Use the space below to check if you were correct
#       5 x = ['Alice', 'Bob', ('Charlie', 'Brown')]
# ----> 6 x[2].append('Junior')
#
# AttributeError: 'tuple' object has no attribute 'append'
